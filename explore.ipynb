# %%
import pandas as pd
import numpy
import json

# %%
df = pd.read_csv("nourish_public_ca_business.csv")

# %%
df.head(10)
# Out:
#                                             name  \
# 0              Lake Hodges Water Recreation Area
# 1                      Apple Country Restaurants
# 2                   United States Postal Service
# 3                             SDSU Global Campus
# 4                                     Center Bar
# 5                                        Chevron
# 6              UCSD Outback Adventures Surf Shop
# 7                                Rehner Orchards
# 8  Naval Medical Center San Diego Emergency Room
# 9                                  Tryyn Gallery
#
#                                              address  avg_rating    zip  \
# 0  Lake Hodges Water Recreation Area, Lake Dr, Es...         4.6  92033
# 1  Apple Country Restaurants, 30270 CA-78, Santa ...         4.1  92070
# 2  United States Postal Service, 16091 San Diegui...         2.7  92091
# 3  SDSU Global Campus, 5250 Campanile Dr, San Die...         4.7  92182
# ...

# %%
with open('statisticalAtlas.json') as f:
    data = json.load(f)
