# %%
import csv
import json

# %%
def parse_csv(file_path):
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        return [row for row in reader]

# %%
def parse_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as jsonfile:
        return json.load(jsonfile)

# %%
def write_json(data, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(data, file, indent=4)

# %%
def merge_json(file_path1, file_path2, output_file_path):
    data1 = read_json(file_path1)
    data2 = read_json(file_path2)

    merged_data = data1 + data2

    write_json(merged_data, output_file_path)

# %%
def join_csv_json(csv_data, json_data, key):
    joined_data = []

    # Convert JSON data to a set for faster lookup
    zip_set = set()
    for zip_group in json_data:
        for zip_code in zip_group.split(', '):
            zip_set.add(zip_code.strip())

    # Iterate through CSV data and join
    for row in csv_data:
        if row[key] in zip_set:
            joined_data.append(row)

    return joined_data

# %%
csv_data = parse_csv('nourish_public_ca_business.csv')
json_data = parse_json('result.json') 

joined_data = join_csv_json(csv_data, json_data, 'zip')

# %%
## all entries near Poway, but not including Poway
joined_data
# Out:
# [{'name': 'Basic Riders Course (BRC)',
#   'address': 'Basic Riders Course (BRC), Miramar Way, San Diego, CA 92145',
#   'avg_rating': '5',
#   'zip': '92145',
#   'categories': '{Driving school}',
#   'city': 'San Diego'},
#  {'name': 'Jamba',
#   'address': 'Jamba, 2761 Gonsalves Ave Building B, San Diego, CA 92145',
#   'avg_rating': '4.3',
#   'zip': '92145',
#   'categories': '{Juice shop,Restaurant}',
#   'city': 'San Diego'},
#  {'name': 'GNC',
#   'address': 'GNC, 2660 45233, Antares Dr, San Diego, CA 92145',
#   'avg_rating': '4',
#   'zip': '92145',
#   'categories': '{Vitamin & supplements store}',
#   'city': 'San Diego'},
#  {'name': 'GameStop Military',
#   'address': 'GameStop Military, 5638 Kelso Rd, San Diego, CA 92145',
#   'avg_rating': '4.5',
#   'zip': '92145',
#   'categories': '{Video game store,Cell phone store,Collectibles store,Electronics store}',
#   'city': 'San Diego'},
#  {'name': "Domino's Pizza",
#   'address': "Domino's Pizza, McAs Air Sta, 5305 Miramar Way, San Diego, CA 92145",
#   'avg_rating': '3.5',
#   'zip': '92145',
#   'categories': '{Pizza delivery,Delivery Restaurant,Takeout Restaurant,Pizza restaurant,Pizza Takeout}',
#   'city': 'San Diego'},
#  {'name': 'California Commercial Asphalt',
#   'address': 'California Commercial Asphalt, 9229 Harris Plant Rd, Asphalt, San Diego, CA 92145',
#   'avg_rating': '3.9',
#   'zip': '92145',
#   'categories': '{Paving materials supplier}',
#   'city': 'San Diego'},
#  {'name': 'MCAS Miramar Veterinary Treatment Facility',
#   'address': 'MCAS Miramar Veterinary Treatment Facility, 6360 Bauer Rd, San Diego, CA 92145',
#   'avg_rating': '4.7',
#   'zip': '92145',
#   'categories': '{Veterinary care}',
#   'city': 'San Diego'},
#  {'name': 'Coast Citrus Distributors',
#   'address': 'Coast Citrus Distributors, 13855 SW 252nd St, San Diego, CA 92145',
#   'avg_rating': '4.6',
#   'zip': '92145',
#   'categories': '{Distribution service}',
#   'city': 'San Diego'},
#  {'name': 'Miramar Fuel Farm',
#   'address': 'Miramar Fuel Farm, 8600 Boyington Rd, San Diego, CA 92145',
#   'avg_rating': '3.9',
#   'zip': '92145',
#   'categories': '{Gas station}',
#   'city': 'San Diego'},
#  {'name': 'The Barn',
#   'address': 'The Barn, San Diego, CA 92145',
#   'avg_rating': '4.5',
#   'zip': '92145',
#   'categories': '{Gym}',
#   'city': 'San Diego'},
#  {'name': 'Consolidated Bachelor Qtrs',
#   'address': 'Consolidated Bachelor Qtrs, Schilt Ave, San Diego, CA 92145',
#   'avg_rating': '3.4',
#   'zip': '92145',
#   'categories': '{Lodging}',
#   'city': 'San Diego'},
#  {'name': "Dunkin'",
#   'address': "Dunkin', 8635 Obregon Ave, San Diego, CA 92145",
#   'avg_rating': '3.6',
#   'zip': '92145',
#   'categories': '{Coffee shop,Bagel shop,Bakery,Breakfast restaurant,Donut shop,Fast food restaurant,Takeout Restaurant}',
#   'city': 'San Diego'},
#  {'name': 'Miramar CBQ',
#   'address': 'Miramar CBQ, 19920 Schilt Ave, San Diego, CA 92145',
#   'avg_rating': '4',
#   'zip': '92145',
#   'categories': '{Lodging}',
#   'city': 'San Diego'},
#  {'name': 'L&L Hawaiian Barbecue',
#   'address': 'L&L Hawaiian Barbecue, 2660 Antares Dr #B, San Diego, CA 92145',
#   'avg_rating': '3.8',
#   'zip': '92145',
#   'categories': '{Hawaiian restaurant,Barbecue restaurant}',
#   'city': 'San Diego'},
#  {'name': 'Auto Skills Center',
#   'address': 'Auto Skills Center, 6673, Miramar Ct, San Diego, CA 92145',
#   'avg_rating': '4.3',
#   'zip': '92145',
#   'categories': '{Auto repair shop}',
#   'city': 'San Diego'},
#  {'name': 'Miramar International Airport',
#   'address': 'Miramar International Airport, MCAS Miramar (NKX, Sparrow Rd, San Diego, CA 92145',
#   'avg_rating': '5',
#   'zip': '92145',
#   'categories': '{Airport}',
#   'city': 'San Diego'},
#  {'name': 'Inns of The Marine Corps',
#   'address': 'Inns of The Marine Corps, 2515, Bauer Rd, San Diego, CA 92145',
#   'avg_rating': '4.6',
#   'zip': '92145',
#   'categories': '{Hotel}',
#   'city': 'San Diego'},
#  {'name': 'Navy Marine Corps Relief Society Thrift Shop',
#   'address': 'Navy Marine Corps Relief Society Thrift Shop, 6360 Bauer Rd, San Diego, CA 92145',
#   'avg_rating': '4.4',
#   'zip': '92145',
#   'categories': '{Thrift store,Army & navy surplus shop,Marines facility}',
#   'city': 'San Diego'},
#  {'name': 'Firestone Complete Auto Care',
#   'address': 'Firestone Complete Auto Care, Bldg 6214, Miramar Rd, San Diego, CA 92145',
#   'avg_rating': '4.1',
#   'zip': '92145',
#   'categories': '{Tire shop,Brake shop,Car battery store,Oil change service,Wheel alignment service}',
#   'city': 'San Diego'},
#  {'name': 'Miramar Nail Spa',
#   'address': 'Miramar Nail Spa, inside Miramar Base, 2257 Elrod Ave, San Diego, CA 92145',
#   'avg_rating': '4.1',
#   'zip': '92145',
#   'categories': '{Nail salon}',
#   'city': 'San Diego'},
#  {'name': 'MCX Autoport Gas Station',
#   'address': 'MCX Autoport Gas Station, Schilt Ave, San Diego, CA 92145',
#   'avg_rating': '5',
#   'zip': '92145',
#   'categories': '{Gas station}',
#   'city': 'San Diego'},
#  {'name': 'Navy Federal Credit Union - ATM',
#   'address': 'Navy Federal Credit Union - ATM, Matthew Ave Bldg 2660, San Diego, CA 92145',
#   'avg_rating': '5',
#   'zip': '92145',
#   'categories': '{ATM,Loan agency}',
#   'city': 'San Diego'},
#  {'name': 'MC Miramar Veterinary Clinic',
#   'address': 'MC Miramar Veterinary Clinic, 6360 Bauer Rd, San Diego, CA 92145',
#   'avg_rating': '4.4',
#   'zip': '92145',
#   'categories': '{Veterinary care}',
#   'city': 'San Diego'},
#  {'name': 'A1 Soils',
#   'address': 'A1 Soils, 9229 Harris Plant Rd, San Diego, CA 92145',
#   'avg_rating': '4.5',
#   'zip': '92145',
#   'categories': '{Landscaping supply store}',
#   'city': 'San Diego'},
#  {'name': 'Starbucks',
#   'address': 'Starbucks, 2760 Gonsalves Ave, San Diego, CA 92145',
#   'avg_rating': '3.4',
#   'zip': '92145',
#   'categories': '{Coffee shop,Cafe,Coffee store,Espresso bar}',
#   'city': 'San Diego'},
#  {'name': 'Miramar Gas Station',
#   'address': 'Miramar Gas Station, San Diego, CA 92145',
#   'avg_rating': '4.5',
#   'zip': '92145',
#   'categories': '{Gas station}',
#   'city': 'San Diego'},
#  {'name': "Denny's",
#   'address': "Denny's, 3750 Anderson Ave Bldg 3750, San Diego, CA 92145",
#   'avg_rating': '4.3',
#   'zip': '92145',
#   'categories': '{Diner,American restaurant,Breakfast restaurant}',
#   'city': 'San Diego'},
#  {'name': 'United States Postal Service',
#   'address': 'United States Postal Service, 45482 Elrod Ave Ste 3, San Diego, CA 92145',
#   'avg_rating': '3.1',
#   'zip': '92145',
#   'categories': '{Post office,Logistics service,Money order service,Shipping and mailing service}',
#   'city': 'San Diego'},
#  {'name': 'Panda Express',
#   'address': 'Panda Express, 4472 Anderson Ave, San Diego, CA 92145',
#   'avg_rating': '4',
#   'zip': '92145',
#   'categories': '{Chinese restaurant,Restaurant}',
#   'city': 'San Diego'},
#  {'name': 'Chipotle Mexican Grill',
#   'address': 'Chipotle Mexican Grill, 2750 Bauer Rd, San Diego, CA 92145',
#   'avg_rating': '4.3',
#   'zip': '92145',
#   'categories': '{Mexican restaurant,Caterer,Fast food restaurant}',
#   'city': 'San Diego'},
#  {'name': 'MCAS Miramar',
#   'address': 'MCAS Miramar, Miramar Way, San Diego, CA 92145',
#   'avg_rating': '4.7',
#   'zip': '92145',
#   'categories': '{Military base,Air force base,United States Armed Forces Base}',
#   'city': 'San Diego'},
#  {'name': 'The HUB',
#   'address': 'The HUB, 5305 Miramar Way, San Diego, CA 92145',
#   'avg_rating': '4.6',
#   'zip': '92145',
#   'categories': '{Educational consultant}',
#   'city': 'San Diego'},
#  {'name': "McDonald's",
#   'address': "McDonald's, 511 Hercules Rd, San Diego, CA 92145",
#   'avg_rating': '3.8',
#   'zip': '92145',
#   'categories': '{Fast food restaurant,Breakfast restaurant,Coffee shop,Hamburger restaurant,Restaurant,Sandwich shop}',
#   'city': 'San Diego'},
#  {'name': 'Hanson',
#   'address': 'Hanson, 9229 Harris Plant Rd Miramar RMC, San Diego, CA 92145',
#   'avg_rating': '4.3',
#   'zip': '92145',
#   'categories': '{Ready mix concrete supplier,Sand & gravel supplier}',
#   'city': 'San Diego'},
#  {'name': 'Gonzales Mess Hall',
#   'address': 'Gonzales Mess Hall, 5500 Miramar Way, San Diego, CA 92145',
#   'avg_rating': '3.4',
#   'zip': '92145',
#   'categories': '{Restaurant}',
#   'city': 'San Diego'},
#  {'name': 'Flying Leatherneck Aviation Museum',
#   'address': 'Flying Leatherneck Aviation Museum, 4203 Anderson Ave, San Diego, CA 92145',
#   'avg_rating': '4.7',
#   'zip': '92145',
#   'categories': '{Museum,Heritage museum,History museum,Tourist attraction}',
#   'city': 'San Diego'},
#  {'name': '3rd MAW Band',
#   'address': '3rd MAW Band, 3379 Anderson Ave, San Diego, CA 92145',
#   'avg_rating': '5',
#   'zip': '92145',
#   'categories': '{Federal government office}',
#   'city': 'San Diego'},
#  {'name': 'VMFAT-101',
#   'address': 'VMFAT-101, San Diego, CA 92145',
#   'avg_rating': '4.4',
#   'zip': '92145',
#   'categories': '{Corporate office}',
#   'city': 'San Diego'}]
